# %%
from nilearn import datasets

# Download the Schaefer 2018 atlas with 100 parcels per hemisphere
schaefer_atlas = datasets.fetch_atlas_schaefer_2018(n_rois=100, resolution_mm=2)

# Print the path to the atlas files
print("Schaefer Atlas path:", schaefer_atlas['maps'])

# Download the Schaefer 2018 atlas with 100 parcels per hemisphere and 17 networks
schaefer_atlas = datasets.fetch_atlas_schaefer_2018(n_rois=100, yeo_networks=17, resolution_mm=2)

# Print the path to the atlas files
print("Schaefer 17-Network Atlas path:", schaefer_atlas['maps'])
# Out:
# Schaefer Atlas path: /home/chrisfoulon/nilearn_data/schaefer_2018/Schaefer2018_100Parcels_7Networks_order_FSLMNI152_2mm.nii.gz
# Downloading data from https://raw.githubusercontent.com/ThomasYeoLab/CBIG/v0.14.3-Update_Yeo2011_Schaefer2018_labelname/stable_projects/brain_parcellation/Schaefer2018_LocalGlobal/Parcellations/MNI/Schaefer2018_100Parcels_17Networks_order.txt ...
#  ...done. (0 seconds, 0 min)
# Downloading data from https://raw.githubusercontent.com/ThomasYeoLab/CBIG/v0.14.3-Update_Yeo2011_Schaefer2018_labelname/stable_projects/brain_parcellation/Schaefer2018_LocalGlobal/Parcellations/MNI/Schaefer2018_100Parcels_17Networks_order_FSLMNI152_2mm.nii.gz ...
# Schaefer 17-Network Atlas path: /home/chrisfoulon/nilearn_data/schaefer_2018/Schaefer2018_100Parcels_17Networks_order_FSLMNI152_2mm.nii.gz
#  ...done. (0 seconds, 0 min)
